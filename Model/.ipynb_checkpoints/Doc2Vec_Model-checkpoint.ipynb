# %% [markdown]
# The purpose of this notebook is to build a Doc2Vec model.

# %%
# Import libraries

import numpy as np
import pandas as pd
import gensim
from scipy.spatial import distance
import pickle

# %% [markdown]
# ## Model Building

# %%
# Read in the course data

course_df = pd.read_csv('../Data/Course_Data/Coursera_Catalog.csv')
print(course_df.shape)
course_df.head(2)
# Out:
# (4416, 10)
#     courseType                                        description  \
# 0  v2.ondemand  Gamification is the application of game elemen...
# 1  v2.ondemand  This course will cover the steps used in weigh...
#
#                                          domainTypes                      id  \
# 0  [{'subdomainId': 'design-and-product', 'domain...  69Bku0KoEeWZtA4u62x6lQ
# 1  [{'subdomainId': 'data-analysis', 'domainId': ...  0HiU7Oe4EeWTAQ4yevf_oQ
#
#            slug specializations                          workload  \
# 0  gamification              []                    4-8 hours/week
# 1  missing-data              []  4 weeks of study, 1-2 hours/week
#
#   primaryLanguages                        certificates  \
# 0           ['en']                    ['VerifiedCert']
# 1           ['en']  ['VerifiedCert', 'Specialization']
#
#                         name
# 0               Gamification
# 1  Dealing With Missing Data

# %%
# Preprocess the course data as a training corpus

# Convert the course descriptions to a list
course_descriptions = course_df['description'].to_list()

# Define a function for basic preprocessing:
# tokenize, lowercase, de-punctuation, document tagging
def read_corpus(corpus):
    for i, doc in enumerate(corpus):
        tokens = gensim.utils.simple_preprocess(doc)
        yield gensim.models.doc2vec.TaggedDocument(tokens, [i])

# Run the function on the list of course descriptions
train_corpus = list(read_corpus(course_descriptions))

# %%
# Examine the first document in the corpus (tag at end)

print(train_corpus[0])
# Out:
# TaggedDocument(['gamification', 'is', 'the', 'application', 'of', 'game', 'elements', 'and', 'digital', 'game', 'design', 'techniques', 'to', 'non', 'game', 'problems', 'such', 'as', 'business', 'and', 'social', 'impact', 'challenges', 'this', 'course', 'will', 'teach', 'you', 'the', 'mechanisms', 'of', 'gamification', 'why', 'it', 'has', 'such', 'tremendous', 'potential', 'and', 'how', 'to', 'use', 'it', 'effectively', 'for', 'additional', 'information', 'on', 'the', 'concepts', 'described', 'in', 'the', 'course', 'you', 'can', 'purchase', 'professor', 'werbach', 'book', 'for', 'the', 'win', 'how', 'game', 'thinking', 'can', 'revolutionize', 'your', 'business', 'in', 'print', 'or', 'ebook', 'format', 'in', 'several', 'languages'], [0])

# %%
# Build a model

# Instantiate the model
model = gensim.models.doc2vec.Doc2Vec(vector_size=50,
                                      window=5,
                                      dm=0,
                                      dm_concat=1,
                                      min_count=2,
                                      epochs=10)

# Create a vocabulary for the model
model.build_vocab(train_corpus)

# Train the model on the corpus
model.train(train_corpus,
            total_examples=model.corpus_count,
            epochs=model.epochs)

# %%
# Self-assess the model

# Infer a vector for a document in the training corpus itself.
vector = model.infer_vector(train_corpus[0].words)

# Find which documents in the training corpus it is most similar to.
sims = model.docvecs.most_similar([vector])
sims
# Out:
# [(0, 0.9621601700782776),
#  (3723, 0.9405094385147095),
#  (1121, 0.9323824048042297),
#  (184, 0.9322988986968994),
#  (2326, 0.9320486783981323),
#  (688, 0.93101567029953),
#  (599, 0.9309282898902893),
#  (3169, 0.9299595355987549),
#  (1019, 0.9295350313186646),
#  (4182, 0.9295138120651245)]

# %% [markdown]
# ### Analysis:
# The model successfully finds that the queried document is most similar to itself in the training corpus. But a similarity score of only .905 still seems low for two exactly identical documents.

# %% [markdown]
# ## Model Evaluation

# %%
# Read in the labeled job descriptions

jobs_test_sample = pd.read_csv('../EDA/jobs_test_sample.csv')
jobs_test_sample
# Out:
#         Job_title                                           Job_Desc  Job_id
# 0  Data Scientist  We are looking for Data Scientists who are int...     901
# 1  Data Scientist  The world's largest and fastest-growing compan...     910
# 2  Data Scientist  \nRole: Data Scientist.\n\nLocation: Foster Ci...     916
# 3  Data Scientist  Upstart is the leading AI lending platform par...     920
# 4  Data Scientist  Why Divvy?Over the past decade, millions of Am...     938
# 5   Data Engineer  About Rocket LawyerWe believe everyone deserve...     935
# 6   Data Engineer  Our mission is to create a world where mental ...    1068
# 7   Data Engineer  Data Engineer \nIf you are a Data Engineer wit...    1089
# 8   Data Engineer  Prabhav Services Inc. is one of the premier pr...    1100
# 9   Data Engineer  About Skupos\nSkupos is the data platform for ...    1105

# %%
# Read in the courses for the labeled job descriptions

courses_test_sample = pd.read_csv('../EDA/courses_test_sample.csv')
courses_test_sample
# Out:
#                                                 name  \
# 0                       The Data Scientist’s Toolbox
# 1                                   Machine Learning
# 2                 Applied Machine Learning in Python
# 3                     Data Visualization with Python
# 4                       Machine Learning with Python
# 5                 Databases and SQL for Data Science
# 6  Google Cloud Platform Big Data and Machine Lea...
# 7           Big Data Modeling and Management Systems
# 8                     Database Management Essentials
# 9  Data Warehouse Concepts, Design, and Data Inte...
#
#                                          description       job_title  \
# 0  In this course you will get an introduction to...  Data Scientist
# 1  Machine learning is the science of getting com...  Data Scientist
# 2  This course will introduce the learner to appl...  Data Scientist
# 3  "A picture is worth a thousand words". We are ...  Data Scientist
# 4  This course dives into the basics of machine l...  Data Scientist
# 5  Much of the world's data resides in databases....   Data Engineer
# 6  This 2-week accelerated on-demand course intro...   Data Engineer
# 7  Once you’ve identified a big data issue to ana...   Data Engineer
# 8  Database Management Essentials provides the fo...   Data Engineer
# 9  This is the second course in the Data Warehous...   Data Engineer
#
#    course_id
# 0       3823
# 1        143
# 2       3165
# 3       3588
# 4       2517
# 5        545
# 6       1015
# 7       4233
# 8       3763
# 9       1311

# %%
# Split the labeled courses by job title

ds_courses = courses_test_sample.loc[courses_test_sample['job_title'] == "Data Scientist"]
de_courses = courses_test_sample.loc[courses_test_sample['job_title'] == "Data Engineer"]
de_courses.reset_index(drop=True, inplace=True)

# %%
# Calculate the model's distance score for this labeled data:
# A lower score is better because the model should recognize
# that these jobs and courses are similar to each other.

# Initiate a list of distances
distances = []

# Loop through the labeled jobs
for i in range(len(jobs_test_sample)):
    
    # Extract the information for the job
    job_title, job_desc, job_id = jobs_test_sample.iloc[i]
    
    # Preprocess the job description
    doc = gensim.utils.simple_preprocess(job_desc)
    
    # Convert the job description into a vector
    job_vec = model.infer_vector(doc)
    
    # Check the job title and loop through relevant courses
    if job_title == 'Data Scientist':
        
        for j in range(len(ds_courses)):
            
            # Extract the course id
            course_id = ds_courses.iloc[j,3]
            
            # Find the distance between the job and course
            d = distance.cosine(job_vec, model.docvecs[course_id])
            
            # Add the result to the distance list
            distances.append(d)
            
    if job_title == 'Data Engineer':
        
        for j in range(len(de_courses)):
            
            # Extract the course id
            course_id = de_courses.iloc[j,3]
            
            # Find the distance between the job and course
            d = distance.cosine(job_vec, model.docvecs[course_id])
            
            # Add the result to the distance list
            distances.append(d)

# Calculate the average distance for all job descriptions
sum_dist = 0
for d in distances:
    sum_dist += d

avg_dist = round(sum_dist / len(distances), 3)
min_dist = round(min(distances), 3)
max_dist = round(max(distances), 3)

print(f"Mean distance score: {avg_dist}")
print(f"Min distance score: {min_dist}")
print(f"Max distance score: {max_dist}")
# Out:
# Mean distance score: 0.165
# Min distance score: 0.057
# Max distance score: 0.273

# %% [markdown]
# ## Detailed Results

# %%
# Define a function to display the results for each labeled job

def display_recs(job_id):
    
    # Initialize a dictionary for the job
    job_dict = {}
    keys = ['job_id', 'job_title', 'course_id', 'course_name', 'labeled', 'distance']
    for key in keys:
        job_dict[key] = []
    
    # Extract info about the job
    i = jobs_test_sample.loc[jobs_test_sample['Job_id'] == job_id].index.values[0]
    job_title = jobs_test_sample.iloc[i]['Job_title']
    job_desc = jobs_test_sample.iloc[i]['Job_Desc']
    
    # Preprocess the job description
    doc = gensim.utils.simple_preprocess(job_desc)
    
    # Convert the job description into a vector
    job_vec = model.infer_vector(doc)
    
    # Get top 5 courses from the model
    top_recs = model.docvecs.most_similar(positive=[job_vec], topn=5)
    
    # Loop through top 5 courses
    for rec in top_recs:
        
        # Add job info to the dictionary
        job_dict['job_id'].append(job_id)
        job_dict['job_title'].append(job_title)
        
        # Add course info to the dicitonary
        course_id = rec[0]
        job_dict['course_id'].append(course_id)
        course_name = course_df.loc[course_id, 'name']
        job_dict['course_name'].append(course_name)
        job_dict['labeled'].append(0)
        
        # Add the distance score to the dictionary
        d = round((1-rec[1]), 3)
        job_dict['distance'].append(d)
    
    # Now loop through the courses I selected as relevant
    if job_title == 'Data Scientist':
        
        for i in range(len(ds_courses)):
            
            # Add job info to the dictionary
            job_dict['job_id'].append(job_id)
            job_dict['job_title'].append(job_title)
            
            # Add course info to the dictionary
            course_id = ds_courses.iloc[i,3]
            job_dict['course_id'].append(course_id)
            course_name = ds_courses.iloc[i,0]
            job_dict['course_name'].append(course_name)
            job_dict['labeled'].append(1)
            
            # Find and add the distance score to the dictionary
            d = distance.cosine(job_vec, model.docvecs[course_id])
            d = round(d,3)
            job_dict['distance'].append(d)
            
    if job_title == 'Data Engineer':
        
        for i in range(len(de_courses)):
            
            # Add job info to the dictionary
            job_dict['job_id'].append(job_id)
            job_dict['job_title'].append(job_title)
            
            # Add course info to the dictionary
            course_id = de_courses.iloc[i,3]
            job_dict['course_id'].append(course_id)
            course_name = de_courses.iloc[i,0]
            job_dict['course_name'].append(course_name)
            job_dict['labeled'].append(1)
            
            # Find and add the distance score to the dictionary
            d = distance.cosine(job_vec, model.docvecs[course_id])
            d = round(d,3)
            job_dict['distance'].append(d)
    
    # Convert the dictionary into a dataframe
    df = pd.DataFrame(job_dict)
    
    # Rank by distance
    df = df.sort_values('distance')
    
    return df

# %%
# Job 1
display_recs(901)
# Out:
#    job_id       job_title  course_id                           course_name  \
# 0     901  Data Scientist       2783           Social Media Data Analytics
# 1     901  Data Scientist       1240  Predictive Analytics and Data Mining
# 2     901  Data Scientist       3238     Building Data Visualization Tools
# 3     901  Data Scientist       4024  Research Data Management and Sharing
# 4     901  Data Scientist       3638  Applying Data Analytics in Marketing
# 8     901  Data Scientist       3588        Data Visualization with Python
# 5     901  Data Scientist       3823          The Data Scientist’s Toolbox
# 7     901  Data Scientist       3165    Applied Machine Learning in Python
# 6     901  Data Scientist        143                      Machine Learning
# 9     901  Data Scientist       2517          Machine Learning with Python
#
#    labeled  distance
# 0        0     0.094
# 1        0     0.101
# 2        0     0.102
# 3        0     0.102
# 4        0     0.102
# 8        1     0.123
# 5        1     0.139
# 7        1     0.147
# 6        1     0.185
# 9        1     0.200

# %%
# Job 2
display_recs(910)
# Out:
#    job_id       job_title  course_id  \
# 0     910  Data Scientist       3120
# 1     910  Data Scientist       3049
# 2     910  Data Scientist       1721
# 3     910  Data Scientist       4147
# 4     910  Data Scientist       1289
# 8     910  Data Scientist       3588
# 5     910  Data Scientist       3823
# 9     910  Data Scientist       2517
# 6     910  Data Scientist        143
# 7     910  Data Scientist       3165
#
#                                        course_name  labeled  distance
# 0  Digital Product Management: Modern Fundamentals        0     0.145
# 1                   Big Data Emerging Technologies        0     0.148
# 2            New Technologies for Business Leaders        0     0.149
# 3       Survey analysis to Gain Marketing Insights        0     0.152
# 4         Marketing analytics: Know your customers        0     0.154
# 8                   Data Visualization with Python        1     0.184
# 5                     The Data Scientist’s Toolbox        1     0.190
# 9                     Machine Learning with Python        1     0.221
# 6                                 Machine Learning        1     0.225
# 7               Applied Machine Learning in Python        1     0.236

# %%
# Job 3
display_recs(916)
# Out:
#    job_id       job_title  course_id  \
# 0     916  Data Scientist        272
# 1     916  Data Scientist       1806
# 2     916  Data Scientist       1553
# 3     916  Data Scientist        602
# 4     916  Data Scientist       3199
# 8     916  Data Scientist       3588
# 5     916  Data Scientist       3823
# 7     916  Data Scientist       3165
# 6     916  Data Scientist        143
# 9     916  Data Scientist       2517
#
#                                          course_name  labeled  distance
# 0                           Data Science Methodology        0     0.046
# 1  AI Workflow: Business Priorities and Data Inge...        0     0.047
# 2  Addressing Large Hadron Collider Challenges by...        0     0.053
# 3               Data Science for Business Innovation        0     0.053
# 4                  Text Retrieval and Search Engines        0     0.053
# 8                     Data Visualization with Python        1     0.055
# 5                       The Data Scientist’s Toolbox        1     0.065
# 7                 Applied Machine Learning in Python        1     0.077
# 6                                   Machine Learning        1     0.081
# 9                       Machine Learning with Python        1     0.103

# %%
# Job 4
display_recs(920)
# Out:
#    job_id       job_title  course_id  \
# 0     920  Data Scientist       3044
# 1     920  Data Scientist       2316
# 2     920  Data Scientist        846
# 3     920  Data Scientist        868
# 4     920  Data Scientist       2821
# 6     920  Data Scientist        143
# 8     920  Data Scientist       3588
# 9     920  Data Scientist       2517
# 5     920  Data Scientist       3823
# 7     920  Data Scientist       3165
#
#                                          course_name  labeled  distance
# 0  Big Data Analysis: Hive, Spark SQL, DataFrames...        0     0.096
# 1  Big Data Essentials: HDFS, MapReduce and Spark...        0     0.103
# 2   Big Data Applications: Machine Learning at Scale        0     0.106
# 3      Tinkering Fundamentals: Motion and Mechanisms        0     0.112
# 4  Compassionate Leadership Through Service Learn...        0     0.115
# 6                                   Machine Learning        1     0.132
# 8                     Data Visualization with Python        1     0.135
# 9                       Machine Learning with Python        1     0.157
# 5                       The Data Scientist’s Toolbox        1     0.164
# 7                 Applied Machine Learning in Python        1     0.192

# %%
# Job 5
display_recs(938)
# Out:
#    job_id       job_title  course_id  \
# 0     938  Data Scientist       2945
# 1     938  Data Scientist       3776
# 2     938  Data Scientist        272
# 3     938  Data Scientist       3049
# 4     938  Data Scientist       4392
# 8     938  Data Scientist       3588
# 5     938  Data Scientist       3823
# 6     938  Data Scientist        143
# 9     938  Data Scientist       2517
# 7     938  Data Scientist       3165
#
#                                          course_name  labeled  distance
# 0  Business Application of Machine Learning and A...        0     0.076
# 1              Data Management for Clinical Research        0     0.078
# 2                           Data Science Methodology        0     0.079
# 3                     Big Data Emerging Technologies        0     0.082
# 4  Python and Machine Learning for Asset Management         0     0.085
# 8                     Data Visualization with Python        1     0.094
# 5                       The Data Scientist’s Toolbox        1     0.108
# 6                                   Machine Learning        1     0.130
# 9                       Machine Learning with Python        1     0.138
# 7                 Applied Machine Learning in Python        1     0.146

# %%
# Job 6
display_recs(935)
# Out:
#    job_id      job_title  course_id  \
# 0     935  Data Engineer       2465
# 1     935  Data Engineer       1721
# 2     935  Data Engineer       3049
# 3     935  Data Engineer       3928
# 4     935  Data Engineer       1235
# 9     935  Data Engineer       1311
# 7     935  Data Engineer       4233
# 6     935  Data Engineer       1015
# 8     935  Data Engineer       3763
# 5     935  Data Engineer        545
#
#                                          course_name  labeled  distance
# 0  Business Intelligence Concepts, Tools, and App...        0     0.149
# 1              New Technologies for Business Leaders        0     0.152
# 2                     Big Data Emerging Technologies        0     0.154
# 3   Wharton Business and Financial Modeling Capstone        0     0.156
# 4                                   Data in Database        0     0.162
# 9  Data Warehouse Concepts, Design, and Data Inte...        1     0.167
# 7           Big Data Modeling and Management Systems        1     0.186
# 6  Google Cloud Platform Big Data and Machine Lea...        1     0.188
# 8                     Database Management Essentials        1     0.195
# 5                 Databases and SQL for Data Science        1     0.207

# %%
# Job 7
display_recs(1068)
# Out:
#    job_id      job_title  course_id  \
# 0    1068  Data Engineer       3044
# 1    1068  Data Engineer        932
# 2    1068  Data Engineer       3831
# 3    1068  Data Engineer       4404
# 4    1068  Data Engineer       3776
# 7    1068  Data Engineer       4233
# 6    1068  Data Engineer       1015
# 5    1068  Data Engineer        545
# 8    1068  Data Engineer       3763
# 9    1068  Data Engineer       1311
#
#                                          course_name  labeled  distance
# 0  Big Data Analysis: Hive, Spark SQL, DataFrames...        0     0.177
# 1  Data and Health Indicators in Public Health Pr...        0     0.190
# 2          Surveillance Systems: The Building Blocks        0     0.191
# 3                                   Cloud Networking        0     0.193
# 4              Data Management for Clinical Research        0     0.200
# 7           Big Data Modeling and Management Systems        1     0.229
# 6  Google Cloud Platform Big Data and Machine Lea...        1     0.245
# 5                 Databases and SQL for Data Science        1     0.258
# 8                     Database Management Essentials        1     0.266
# 9  Data Warehouse Concepts, Design, and Data Inte...        1     0.268

# %%
# Job 8
display_recs(1089)
# Out:
#    job_id      job_title  course_id  \
# 0    1089  Data Engineer       3044
# 1    1089  Data Engineer        225
# 2    1089  Data Engineer       3853
# 3    1089  Data Engineer       2548
# 4    1089  Data Engineer       3776
# 7    1089  Data Engineer       4233
# 8    1089  Data Engineer       3763
# 5    1089  Data Engineer        545
# 9    1089  Data Engineer       1311
# 6    1089  Data Engineer       1015
#
#                                          course_name  labeled  distance
# 0  Big Data Analysis: Hive, Spark SQL, DataFrames...        0     0.085
# 1                      Big Data, Genes, and Medicine        0     0.113
# 2                               SQL for Data Science        0     0.116
# 3                               Requirements Writing        0     0.120
# 4              Data Management for Clinical Research        0     0.122
# 7           Big Data Modeling and Management Systems        1     0.156
# 8                     Database Management Essentials        1     0.157
# 5                 Databases and SQL for Data Science        1     0.165
# 9  Data Warehouse Concepts, Design, and Data Inte...        1     0.178
# 6  Google Cloud Platform Big Data and Machine Lea...        1     0.228

# %%
# Job 9
display_recs(1100)
# Out:
#    job_id      job_title  course_id  \
# 0    1100  Data Engineer       4233
# 1    1100  Data Engineer       3976
# 2    1100  Data Engineer       4253
# 7    1100  Data Engineer       4233
# 3    1100  Data Engineer       2936
# 4    1100  Data Engineer       2099
# 9    1100  Data Engineer       1311
# 8    1100  Data Engineer       3763
# 5    1100  Data Engineer        545
# 6    1100  Data Engineer       1015
#
#                                          course_name  labeled  distance
# 0           Big Data Modeling and Management Systems        0     0.093
# 1                Big Data Integration and Processing        0     0.093
# 2           Responsive Website Tutorial and Examples        0     0.093
# 7           Big Data Modeling and Management Systems        1     0.093
# 3                                Building R Packages        0     0.094
# 4                           Introduction to Big Data        0     0.095
# 9  Data Warehouse Concepts, Design, and Data Inte...        1     0.110
# 8                     Database Management Essentials        1     0.112
# 5                 Databases and SQL for Data Science        1     0.132
# 6  Google Cloud Platform Big Data and Machine Lea...        1     0.168

# %%
# Job 10
display_recs(1105)
# Out:
#    job_id      job_title  course_id  \
# 0    1105  Data Engineer       3044
# 1    1105  Data Engineer       3049
# 2    1105  Data Engineer       1874
# 3    1105  Data Engineer       4025
# 4    1105  Data Engineer       3238
# 9    1105  Data Engineer       1311
# 7    1105  Data Engineer       4233
# 8    1105  Data Engineer       3763
# 5    1105  Data Engineer        545
# 6    1105  Data Engineer       1015
#
#                                          course_name  labeled  distance
# 0  Big Data Analysis: Hive, Spark SQL, DataFrames...        0     0.129
# 1                     Big Data Emerging Technologies        0     0.134
# 2                    Executive Data Science Capstone        0     0.140
# 3  Amazon DynamoDB: Building NoSQL Database-Drive...        0     0.143
# 4                  Building Data Visualization Tools        0     0.144
# 9  Data Warehouse Concepts, Design, and Data Inte...        1     0.155
# 7           Big Data Modeling and Management Systems        1     0.167
# 8                     Database Management Essentials        1     0.169
# 5                 Databases and SQL for Data Science        1     0.183
# 6  Google Cloud Platform Big Data and Machine Lea...        1     0.193

# %% [markdown]
# ### Analysis:
# The architecture works, but the model does not appear to be very effective: Digital Product Management is definitely not the most relevant course on Coursera for the Data Scientist position at BrightIdea. Why does my model think it is? (The resoning is difficult to see just by looking at the two documents it matched together.) How can I improve the model's performance?

# %% [markdown]
# ## Pickle the Model

# %%
# Save the model to the API file
# by serializing it with the pickle library.

pickle.dump(model, open('../API/model.p', 'wb'))
